# %%
import json_tricks
answer = {}


inputs = json_tricks.load(open('inputs/inputs.json', 'r'))

# %% [markdown]
# # Backpropagation Practice

# %% [markdown]
# You are given a graph of operations:

# %% [markdown]
# <img src="imgs/task_2_4_graph_02.png" width="400" height="300" />

# %% [markdown]
# # Task 1
#
# Write function that calculates value of this graph for any given input vector `x` and set of coefficients $b_1, b_2, c_1, c_2$ packed as vector of weights `w`.
# In this function also return all the $z$ values.

# %%
import numpy as np
def graph_value(x, w):
    c1, c2, b1, b2 = w
    # Пример графа:
    # z1 = c1 * x[0] + b1
    # z2 = c2 * x[1] + b2
    # y = z1 + z2
    
    z1 = c1 * x[0] + b1
    z2 = c2 * x[1] + b2
    y = z1 + z2
    
    values = {
        'z1': z1,
        'z2': z2,
        'y': y
    }
    return y, values

# %%
answer['graph_value'] = [graph_value(**input) for input in inputs]

# %% [markdown]
# # Task 2
#
# In this graph, find all direct derivatives of all the values over $z$ or $x$ or $w$.
#
# For example, if $y = z_8 + z_9$, you need to find only $\partial_{z_9} y$ and $\partial_{z_8} y$ for that operation.
#
# You have to do that for all the intermediate signals.
#
# Write the result in form of dictionary, for example, $\partial_{z_9} y$:
#
# ```
# ['dy_dz9'] = 1
# ```

# %%
def graph_derivatives(x, w):
    c1, c2, b1, b2 = w
    
    derivs = {
        'dy_dz1': 1,        # dy/dz1
        'dy_dz2': 1,        # dy/dz2
        
        'dz1_dc1': x[0],    # dz1/dc1
        'dz1_db1': 1,       # dz1/db1
        
        'dz2_dc2': x[1],    # dz2/dc2
        'dz2_db2': 1,       # dz2/db2
    }
    return derivs
    return res

# %%
answer['graph_derivatives'] = [graph_derivatives(**input) for input in inputs]

# %% [markdown]
# # Task 3
#
# Using the values of the derivatives, calculated above:
# - extract a dictionary of values that are needed to calculate $\partial_{c_1} y$
# - calculate that derivative

# %%
def dy_dc1(x, w):
    derivs = graph_derivatives(x, w)
    selected_derivs = {
        'dy_dz1': derivs['dy_dz1'],
        'dz1_dc1': derivs['dz1_dc1']
    }
    dy_dc1_val = derivs['dy_dz1'] * derivs['dz1_dc1']  # Цепное правило
    return selected_derivs, dy_dc1_val

# %%
answer['dy_dc1'] = [dy_dc1(**input) for input in inputs]

# %% [markdown]
# # Task 4
# Using the values of the derivatives, calculated above:
# - extract a dictionary of values that are needed to calculate $\partial_{c_2} y$
# - calculate that derivative

# %%
def dy_dc2(x, w):
    derivs = graph_derivatives(x, w)
    selected_derivs = {
        'dy_dz2': derivs['dy_dz2'],
        'dz2_dc2': derivs['dz2_dc2']
    }
    dy_dc2_val = derivs['dy_dz2'] * derivs['dz2_dc2']
    return selected_derivs, dy_dc2_val

# %%
answer['dy_dc2'] = [dy_dc2(**input) for input in inputs]

# %% [markdown]
# # Task 5
# Using the values of the derivatives, calculated above:
# - extract a dictionary of values that are needed to calculate $\partial_{b_1} y$
# - calculate that derivative

# %%
def dy_db1(x, w):
    derivs = graph_derivatives(x, w)
    selected_derivs = {
        'dy_dz1': derivs['dy_dz1'],
        'dz1_db1': derivs['dz1_db1']
    }
    dy_db1_val = derivs['dy_dz1'] * derivs['dz1_db1']
    return selected_derivs, dy_db1_val

# %%
answer['dy_db1'] = [dy_db1(**input) for input in inputs]

# %% [markdown]
# # Task 6
# Using the values of the derivatives, calculated above:
# - extract a dictionary of values that are needed to calculate $\partial_{b_2} y$
# - calculate that derivative

# %%
def dy_db2(x, w):
    derivs = graph_derivatives(x, w)
    selected_derivs = {
        'dy_dz2': derivs['dy_dz2'],
        'dz2_db2': derivs['dz2_db2']
    }
    dy_db2_val = derivs['dy_dz2'] * derivs['dz2_db2']
    return selected_derivs, dy_db2_val


# Заполняем словарь ответов для всех входных данных
answer['graph_value'] = [graph_value(**inp) for inp in inputs]
answer['graph_derivatives'] = [graph_derivatives(**inp) for inp in inputs]
answer['dy_dc1'] = [dy_dc1(**inp) for inp in inputs]
answer['dy_dc2'] = [dy_dc2(**inp) for inp in inputs]
answer['dy_db1'] = [dy_db1(**inp) for inp in inputs]
answer['dy_db2'] = [dy_db2(**inp) for inp in inputs]

# %%
answer['dy_db2'] = [dy_db2(**input) for input in inputs]

# %%
json_tricks.dump(answer, '.answer.json')
# Out:
# '{"graph_value": [[-0.35715492681385286, {"z1": 0.08756268889443303, "z2": -0.4447176157082859, "y": -0.35715492681385286}], [-1.2541679931050733, {"z1": -1.2048176596334017, "z2": -0.04935033347167167, "y": -1.2541679931050733}], [-0.04013520324456632, {"z1": -1.4301961573540372, "z2": 1.3900609541094708, "y": -0.04013520324456632}], [-2.3691996451134045, {"z1": -1.2633161637508712, "z2": -1.1058834813625336, "y": -2.3691996451134045}], [-0.2240780229801751, {"z1": 0.025942329669334963, "z2": -0.25002035264951006, "y": -0.2240780229801751}], [-2.3493522477179694, {"z1": 0.8306662814747501, "z2": -3.1800185291927194, "y": -2.3493522477179694}], [0.2466420656945219, {"z1": 0.4610568669873224, "z2": -0.2144148012928005, "y": 0.2466420656945219}], [0.9842197353145568, {"z1": -0.2896502423005518, "z2": 1.2738699776151086, "y": 0.9842197353145568}], [0.7250309912675248, {"z1": -0.5655608210659617, "z2": 1.2905918123334865, "y": 0.7250309912675248}], [0.15361235459822642, {"z1": -0.533969434309211, "z2": 0.6875817889074374, "y": 0.15361235459822642}], [2.920979566641245, {"z1": 1.3426530403651253, "z2": 1.5783265262761197, "y": 2.920979566641245}], [1.2259918210166025, {"z1": 0.33535415137690516, "z2": 0.8906376696396974, "y": 1.2259918210166025}], [1.1678793474978646, {"z1": 0.18090215879539445, "z2": 0.9869771887024701, "y": 1.1678793474978646}], [0.22968