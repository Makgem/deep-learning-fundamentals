# %%
import json_tricks
import torch
import numpy as np
import matplotlib.pyplot as plt
import random

# This is important for reproducibility
random.seed(42)
np.random.seed(42)
torch.manual_seed(42)
torch.set_default_dtype(torch.float64)

if torch.cuda.is_available():
    torch.cuda.manual_seed(42)

answer = {}

# %% [markdown]
# # Preparation

# %% [markdown]
# In this notebook we will be working on toy problem of reconstructing the hidden
# dependency. We will work with synthetic dataset. As a basic example, we will
# start with data
#
# $$f(x) = \sin(x) + \epsilon,$$
#
# where $\epsilon$ is random noise that will simulate measurement inaccuracies.
#
# Our task will be to prepare the network $Net(x)$ that will accept single value $x$
# as an argument and yield single value $y$ as a forecast.
#
# Ideally the network should be as close to the hidden dependency as possible:
#
# $$Net(x) \rightarrow \sin(x)$$
#
# We will create all the modules that are necessary to train a network:
# - network (2 layer FCNN)
# - loss function (MSE)
# - optimizer (AdamW)
#
# We will also create a traingin cycle that consists of:
# - forward step
# - loss calculation
# - backpropagation
# - optimizer step

# %% [markdown]
# # Generating the dataset

# %% [markdown]
# First we will generate the clean samples

# %%
import torch
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['figure.figsize'] = (10.0, 5.0)

x_train = torch.rand(100)
x_train = x_train * 20.0 - 10.0
y_train = torch.sin(x_train)

y_train = torch.sin(x_train)

plt.plot(x_train.numpy(), y_train.numpy(), 'o')
plt.title('$y = sin(x)$');

# %% [markdown]
# Secondly, generate the noise that will be added to the training data

# %%
noise = torch.randn(y_train.shape) / 10.0
y_train = y_train + noise

x_train.unsqueeze_(1)
y_train.unsqueeze_(1)
# Out:
# tensor[100, 1] f64 x∈[-1.100, 1.233] μ=0.040 σ=0.729

# %% [markdown]
# Lastly, add the noise to the clean data and get the spoiled data that we will use for training

# %%
y_train = y_train + noise
plt.plot(x_train.numpy(), y_train.numpy(), 'o')
plt.title('noisy sin(x)')
plt.xlabel('x_train')
plt.ylabel('y_train');

# %%
x_train.unsqueeze_(1);
y_train.unsqueeze_(1);

# %% [markdown]
# # Validation dataset

# %% [markdown]
# For validation we will use only clean equidistant data. Thus we will not generate noise for this set.

# %%
x_validation = torch.linspace(-10, 10, 100)
y_validation = torch.sin(x_validation)
x_validation.unsqueeze_(1)
y_validation.unsqueeze_(1)
# Out:
# tensor[100, 1] f64 x∈[-0.999, 0.999] μ=-1.110e-18 σ=0.693

# %%
x_validation.unsqueeze_(1)
y_validation.unsqueeze_(1);

# %% [markdown]
# # Model construction

# %% [markdown]
# Fill out the class for 2-layer Feed Forward Neural Network with Sigmoid hidden layer.
#
# Class should consist of two methods:
# * `__init__` -- constructor, where the layers should be defined:
#     * `Linear 1 -> n_hidden_neurons`
#     * `sigmoid` activation
#     * `Linear n_hidden_neurons -> 1`
# * `forward` -- pass the signal through the network:
#     * `x -> linear 1 -> sigmoid -> linear 2`

# %%
class SineNet(torch.nn.Module):
    def __init__(self, n_hidden_neurons):
        super().__init__()
        self.linear1 = torch.nn.Linear(1, n_hidden_neurons)
        self.activation = torch.nn.Sigmoid()
        self.linear2 = torch.nn.Linear(n_hidden_neurons, 1)

    def forward(self, x):
        x = self.linear1(x)
        x = self.activation(x)
        x = self.linear2(x)
        return x
sine_net = SineNet(20)

# %% [markdown]
# # Prediction

# %% [markdown]
# Here we will make prediction using our neural network. The main method here is `forward` that we have programmed within our `torch.Module` class.
#
# Below we will plot out predictions to understand how they are related to the validation data.

# %%
y_pred_init = sine_net.forward(x_validation)
answer['init_pred'] = y_pred_init.detach().numpy()

# %% [markdown]
# We see that the untrained neural network predict something, maybe even some dependency, but it is not related to the dependency that we want to reconstruct.
#
# Now let us train the network (tune the parameters to minimize the misfit between the labels and predictions).

# %% [markdown]
# # Loss function

# %% [markdown]
# Now we will define the function using which we will measure the misfit.
#
# The requirements for this function are:
# * the lower the loss is the better the predictions are
# * slope should be non-zero for the majority of the locations
#
# In our case it will be mean squared error:
# $$\frac{1}{N} \sum_{i=1}^N \left(Net(x_i) - t_i\right)^2$$
#
# The lower this deviation is, the closer the prediction of the Neural Network to target.
#
# Code this loss function. Note that `pred` and `target` are the vectors.

# %%
def loss(pred, target):
    return torch.mean((pred - target) ** 2)

answer['loss'] = [loss(torch.tensor([v], dtype=torch.float64), torch.tensor([0.0], dtype=torch.float64)).item() for v in np.linspace(-10, 10, 100)]

# %% [markdown]
# # Optimizer

# %% [markdown]
# Now we have to tune the parameters minimising the loss function. Select `AdamW` optimizer from `torch.optim`.
#
# As a first argument you should pass which parameters the optimizer should take care of. One can access whole set of parameters of `torch.Module` using `parameters()` method.
#
# Set `lr` (learning rate) to `1.0e-2`.

# %%
optimizer = torch.optim.AdamW(sine_net.parameters(), lr=1e-2)

# %% [markdown]
# # Training procedure

# %% [markdown]
# Now everything is ready for training.
#
# Compound the training cycle out of the following step:
# 1. reset the gradients for trainable weights (`zero_grad()` method of the optimizer)
# 2. forward signal propagation through the network (take vector of input signals `x_train` and call `forward` method of the `torch.nn.Module` with that `x_train` as an argument)
# 3. loss value comutation (take`loss` that we have created above and comute misfit of prediction and target labels `y_train`)
# 4. backpropagation through the network, computation of loss derivatives through every of the weights of the network (`backward` method of `torch.nn.Module`)
# 5. optimizer step as all of the gradients for every of the weights are known (`step` method of the `Optimizer`)
#
# Repeat the steps above for some amount of times. Say, for `1000` and observe the change of the network predictions

# %%
for epoch in range(1000):
    optimizer.zero_grad()
    y_pred_train = sine_net(x_train)
    loss_value = loss(y_pred_train, y_train)
    loss_value.backward()
    optimizer.step()

# %%
import lovely_tensors as lt
lt.monkey_patch()

print(x_train.dtype)
print(y_train.dtype)
print(x_train)
print(y_train)
print(x_validation)
# Out:
# torch.float64
# torch.float64
# tensor[100, 1, 1] f64 x∈[-9.867, 9.969] μ=-0.997 σ=6.032
# tensor[100, 1, 100] f64 n=10000 (78Kb) x∈[-1.320, 1.489] μ=0.044 σ=0.734
# tensor[100, 1, 1] f64 x∈[-10.000, 10.000] μ=-3.553e-17 σ=5.861

# %% [markdown]
# # Conclusion

# %% [markdown]
# In this notebook we have covered all of the steps that the coder encounters while programming training procedure of a Neural Network.
#
# In serious projects every part of this process contatins tonns of code, but the philosophy everywhere is the same:
#
# * Get data
# * Define the Network
# * Define Loss
# * Select optimizer
# * Run training cycle

# %%
json_tricks.dump(answer, open('.answer.json', 'w'))
# Out:
# '{"init_pred": {"__ndarray__": [[[-0.03341551704327114]], [[-0.033504265524207905]], [[-0.03359759483622102]], [[-0.03369590087459093]], [[-0.03379958125259494]], [[-0.03390903128948761]], [[-0.03402463949036741]], [[-0.03414678254185119]], [[-0.03427581987878603]], [[-0.034412087919831136]], [[-0.034555894126773096]], [[-0.03470751111773032]], [[-0.03486717116263097]], [[-0.0350350615161103]], [[-0.03521132120488754]], [[-0.03539604009142]], [[-0.03558926129186374]], [[-0.03579098834348057]], [[-0.036001198904382054]], [[-0.03621986723595014]], [[-0.03644699827257339]], [[-0.03668267672725892]], [[-0.03692713541037168]], [[-0.03718084773477362]], [[-0.0374446502071869]], [[-0.03771990149745602]], [[-0.038008685329260106]], [[-0.03831406478853655]], [[-0.03864039547078932]], [[-0.03899370387263834]], [[-0.03938213516852118]], [[-0.039816470497495204]], [[-0.040310707539415874]], [[-0.04088268888308755]], [[-0.0415547499564006]], [[-0.042354341815087765]], [[-0.04331456406854936]], [[-0.0444745206587098]], [[-0.04587938829772481]], [[-0.04758006791336619]], [[-0.04963227915873719]], [[-0.05209496452430329]], [[-0.05502790167484828]], [[-0.05848848861700745]], [[-0.06252777080970615]], [[-0.06718591899765622]], [[-0.07248752567487735]], [[-0.07843723651467835]], [[-0.08501632915600785]], [[-0.09218085198533274]], [[-0.09986181026251764]], [[-0.10796763604432083]], [[-0.11638884022265719]], [[-0.12500439133531563]], [[-0.13368908178200414]], [[-0.1423209981667302]], [[-0.15078824009895012]], [[-0.15899421367366165]], [[-0.1668611052603263]], [[-0.17433144446119583]], [[-0.18136792638904534]], [[-0.18795184186108685]], [[-0.19408054816475243]], [[-0.19976441463155423]], [[-0.2050236209808294]], [[-0.20988509936914104]], [[-0.21437981611623877]], [[-0.21854050183666704]], [[-0.22239986771403478]], [[-0.2259892938081081]], [[-0.2293379417525994]], [[-0.2324722261220449]], [[-0.23541557248221548]], [[-0.238188392084455]], [[-0.2408082101894923]], [[-0.24328989463923437]], [[-0.2456459417428554]], [[-0.24788678661781624]], [[-0.25002111412826367]], [[-0.2520561541590023]], [[-0.25399795107162626]], [[-0.25585160188814726]], [[-0.2576214612020393]], [[-0.25931131322997425]], [[-0.26092451299694475]], [[-0.26246409958508754]], [[-0.2639328848391975]], [[-0.26533352104785446]], [[-0.26666855101820874]], [[-0.26794044371924763]], [[-0.26915161834545787]], [[-0.2703044592950803]], [[-0.27140132419539464]], [[-0.2724445467617078]], [[-0.27343643595895484]], [[-0.2743792726513212]], [[-0.2752753046782954]], [[-0.2761267410846543]], [[-0.27693574605495896]], [[-0.2777044329571523]]], "dtype": "float64", "shape": [100, 1, 1], "Corder": true}, "loss": [100.0, 96.00040812162024, 92.08244056728904, 88.24609733700643, 84.49137843077237, 80.81828384858687, 77.22681359044994, 73.7169676563616, 70.2887460463218, 66.94214876033058, 63.67717579838791, 60.49382716049382, 57.39210284664831, 54.37200285685134, 51.43352719110294, 48.576675849403124, 45.80144883175187, 43.10784613814917, 40.49586776859504, 37.96551372308948, 35.51678400163248, 33.149678604224064, 30.864197530864196, 28.660340781552907, 26.538108356290174, 24.497500255076016, 22.538516477910417, 20.661157024793393, 18.865421895724925, 17.151311090705033, 15.5188246097337, 13.96796245281094, 12.498724619936741, 11.111111111111109, 9.80512192633405, 8.58075706560555, 7.438016528925621, 6.376900316294255, 5.39740842771146, 4.499540863177226, 3.68329762269156, 2.9486787062544666, 2.295684113865933, 1.7243138455259668, 1.234567901234567, 0.8264462809917373, 0.4999489847974704, 0.2550760126517704, 0.09182736455463712, 0.010203040506070672, 0.010203040506070672, 0.09182736455463712, 0.2550760126517704, 0.4999489847974704, 0.8264462809917341, 1.234567901234567, 1.7243138455259668, 2.295684113865933, 2.948678706254461, 3.68329762269156, 4.499540863177226, 5.39740842771146, 6.37690031629425, 7.438016528925616, 8.58075706560555, 9.80512192633405, 11.111111111111114, 12.498724619936736, 13.9679624528109 ...
